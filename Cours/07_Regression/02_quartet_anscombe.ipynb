# %% [markdown]
# # Le quartet d'Anscombe
#
# Ce notebook accompagne l'exercice 7.2. Quatre jeux de onze points partagent presque les mêmes indicateurs numériques et la même droite des moindres carrés, mais leurs géométries sont très différentes. L'exemple montre pourquoi une régression doit être regardée, pas seulement résumée.

# %% [markdown]
# ## Parcours
#
# 1. [Indicateurs numériques](#indicateurs-anscombe)
# 2. [Représentations](#figures-anscombe)
# 3. [Pertes robustes](#robuste-anscombe)

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.linear_model import HuberRegressor, LinearRegression, QuantileRegressor

print(f"NumPy {np.__version__}, scikit-learn {sklearn.__version__}")
# Out:
# NumPy 2.5.2, scikit-learn 1.9.0

# %% [markdown]
# <a id="indicateurs-anscombe"></a>
# ## 1. Indicateurs numériques
#
# Les données ci-dessous sont celles d'Anscombe. Calculez les moyennes, variances, corrélations, coefficients de la droite des moindres carrés et pertes quadratiques.

# %%
x_commun = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], dtype=float)
donnees = {
    "I": (x_commun, np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])),
    "II": (x_commun, np.array([9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])),
    "III": (x_commun, np.array([7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])),
    "IV": (np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8], dtype=float),
           np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89])),
}

# %%
# À compléter.

# %% [markdown]
# <a id="figures-anscombe"></a>
# ## 2. Représentations
#
# Représentez les quatre ensembles avec la même échelle et superposez leurs droites. Décrivez ce que les indicateurs précédents ne montrent pas.

# %%
# À compléter.

# %% [markdown]
# <a id="robuste-anscombe"></a>
# ## 3. Pertes robustes
#
# Comparez les moindres carrés, la régression médiane — associée à la perte absolue — et Huber. Les pertes robustes corrigent-elles toutes les difficultés du quartet ?

# %%
# À compléter.

# %% [markdown]
# ## Bilan
#
# Des indicateurs identiques peuvent cacher des mécanismes géométriques incompatibles. Une étude de régression doit confronter données, résidus, classe de machines et fonction de perte.
